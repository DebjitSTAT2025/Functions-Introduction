# %%
1.Introduction to Functions
2.Defining Functions
3.Calling Functions
4.Function parameters
5.Default Parameters
6.Varibale-Length Arguments
7.Return Statement

# %%
Definition
A function is a block of code
that performs a specific task.Functions help in organizing code,resuing code and improving readability

# %%
##syntax
def function_name(parameters):
    """Docstring"""
    # Function body
     return expression

# %%
##Return multiple parameters
def multiply(a,b):
    return a*b,a

multiple(2,3)

# %%
def add(a,b):
    c=a+b
    return c

# %%
def greet(name):
    print(f"Hello{name}")

# %%
###Default parameteres
def greet(name="Guest"):
     print(f"Hello {name} Welcome To the paradise")
greet("Krish")
# Out:
# Hello Krish Welcome To the paradise

# %%
###Variable LengtH Argumants
##Positional And Keywords arguments
def print_numbers(*krish):
    for number in krish:
        print(number)

# %%
print_numbers(1,2,3,4,5,6,7,8,"Krish")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# Krish

# %%
def print_details(*args,**kwargs):
 for val in kwargs.items():
     print(f"Positional argument :{val}")

 for key,value in kwargs.items():
     print(f"{key}:{value}")

# %%
print_details(1,2,3,4,"Krish",name="Krish",age="32",country="India")
# Out:
# Positional argument :('name', 'Krish')
# Positional argument :('age', '32')
# Positional argument :('country', 'India')
# name:Krish
# age:32
# country:India

# %%
###Return statements
def multiply(a,b):
    return a*b,a

multiply(2,3)
# Out:
# 6
